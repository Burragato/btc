# %%
print("MAPE tra 'y' e 'predictions': {0:.2f}%".format(metrics['MAPE']*100)) 
print("MAPE tra 'y' e 'Naive': {:.2f}%".format(metricsNaive['MAPE']*100))


print("MSE tra 'y' e predictions: {}".format(format_with_apostrophe(metrics['MSE']))) 

print("MSE tra 'y' e Naive: {}".format(format_with_apostrophe(metricsNaive['MSE'])))
