# %%
train = data[:training_data_len] valid = data[training_data_len:] valid['Predictions'] = predictions;
valid['Naive'] = valid.close.shift(1)
plt.figure(figsize=(16,6)) plt.title('Model') plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)

# plt.plot(train['close'])
plt.plot(valid[['close',  'Predictions']]) plt.legend([ 'Val', 'Predictions'], loc='lower right')

# Aggiungi righe verticali per ogni giorno
for date in valid.index:
plt.axvline(x=date, color='gray', linestyle='-', alpha=0.1)

plt.show()
