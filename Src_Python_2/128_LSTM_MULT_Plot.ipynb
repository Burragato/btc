# %%
valid = dataset.iloc[training_data_len:, 0] 
valid = valid.to_frame() 
valid['Predictions'] = predictions

valid['Naive'] = valid.close.shift(1) plt.figure(figsize=(16, 6)) plt.title('Model')
plt.xlabel('Date', fontsize=18) 
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(valid[['close', 'Predictions', 'Naive']]) 
plt.legend(['Val', 'Predictions', 'Naive'], loc='lower right')

# Aggiungi righe verticali per ogni giorno
for date in valid.index:
plt.axvline(x=date, color='gray', linestyle='-', alpha=0.1)

plt.show()
