# %%
test_data = scaled_data[training_data_len - n_past: , :]

x_test = []
y_test = dataset.iloc[training_data_len:, 0]
for i in range(n_past, len(test_data) - n_future +1): x_test.append(test_data[i - n_past:i, 0:scaled_data.shape[1]])

x_test = np.array(x_test)

print('x_test shape == {}.'.format(x_test.shape)) 

print('y_test shape == {}.'.format(y_test.shape))
