# %%
from sklearn.metrics import mean_squared_error

mape_predictions = np.mean(np.abs((test_predictions2['y'] - test_predictions2['predictions']) / test_predictions2['y'])) * 100
# Calcola il MAPE tra 'y' e 'Naive'
mape_naive = np.mean(np.abs((test_predictions2['y'] - test_predictions2['Naive']) / test_predictions2['y'])) * 100

mse_predictions = mean_squared_error(test_predictions2['y'], test_predictions2['predictions'])
