# %%
predictions = model.predict(x_test)

prediction_copies = np.repeat(predictions, df_for_training_scaled.shape[1], 
     axis=-1)

predictions = scaler.inverse_transform(prediction_copies)[:,0]

predictions
