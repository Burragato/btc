# %%
test_naive=pd.DataFrame()
test_naive["Naive"]=result_df['Naive']
test_naive["y_test"]=y_test
test_naive_clean=test_naive.dropna()
metrics = regression_metrics(test_naive_clean["Naive"], test_naive_clean["y_test"])
metrics
