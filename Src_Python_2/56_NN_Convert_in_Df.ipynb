# %%
# Converti predictions in DataFrame e assegna l'indice di y_test
predictions_df = pd.DataFrame(predictions, index=y_test.index, columns=['Predictions'])

# Crea un nuovo DataFrame unendo predictions_df e y_test
result_df = pd.concat([y_test, predictions_df], axis=1)

# print(result_df)
