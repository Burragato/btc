# %%
df['year'] = df.index.year 
df['month'] = df.index.month 
df['day'] = df.index.day
# df['hour'] = df.index.hour #df['week'] = df.index.weekofyear df['dayofweek']=df.index.dayofweek 
#df['quarte']=df.index.quarter
# df['date']=df.index.date 
#QUESTO MI SERVE PER UNIRE I DATASET FEER AND GREED
# df['date']=pd.to_datetime(df.date)
