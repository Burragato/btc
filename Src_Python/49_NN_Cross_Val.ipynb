# %%
def cross_validation(dataframe, giorni_da_eliminare, giorni_test, giorni_train):
if giorni_da_eliminare == 0: df = dataframe
else:
df = dataframe.iloc[:-giorni_da_eliminare] df_test = df[-giorni_test:]
start_train = -giorni_train-giorni_test df_train = df[start_train:-giorni_test] return df_test, df_train

test_data, train_data = cross_validation(X_selected, giorni_da_eliminare, giorni_test, giorni_train)
