# %%
df_melted = pd.DataFrame() 
df_melted["timestamp"] = df.index 
df_melted["close"] = df['close'].values 
df_melted['Symbols'] = ticker df_melted.tail(3)
